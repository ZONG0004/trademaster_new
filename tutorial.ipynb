#   6600K .......... .......... .......... .......... .......... 86% 7.57M 0s
#   6650K .......... .......... .......... .......... .......... 86% 7.46M 0s
#   6700K .......... .......... .......... .......... .......... 87% 8.32M 0s
#   6750K .......... .......... .......... .......... .......... 88% 6.87M 0s
#   6800K .......... .......... .......... .......... .......... 88% 7.75M 0s
#   6850K .......... .......... .......... .......... .......... 89% 7.35M 0s
#   6900K .......... .......... .......... .......... .......... 90% 10.4M 0s
#   6950K .......... .......... .......... .......... .......... 90% 8.26M 0s
#   7000K .......... .......... .......... .......... .......... 91% 8.74M 0s
#   7050K .......... .......... .......... .......... .......... 92% 9.12M 0s
#   7100K .......... .......... .......... .......... .......... 92% 10.5M 0s
#   7150K .......... .......... .......... .......... .......... 93% 11.1M 0s
#   7200K .......... .......... .......... .......... .......... 94% 11.7M 0s
#   7250K .......... .......... .......... .......... .......... 94% 11.7M 0s
#   7300K .......... .......... .......... .......... .......... 95% 11.4M 0s
#   7350K .......... .......... .......... .......... .......... 96% 8.75M 0s
#   7400K .......... .......... .......... .......... .......... 96% 11.7M 0s
#   7450K .......... .......... .......... .......... .......... 97% 5.98M 0s
#   7500K .......... .......... .......... .......... .......... 97% 20.1M 0s
#   7550K .......... .......... .......... .......... .......... 98% 11.6M 0s
#   7600K .......... .......... .......... .......... .......... 99% 8.96M 0s
#   7650K .......... .......... .......... .......... .......... 99% 7.50M 0s
#   7700K ......                                                100% 88.1M=0.7s
#
# 2022-05-17 01:37:02 (10.3 MB/s) - ‘./experiment/dj30/dataset/dj30.csv’ saved [7891038/7891038]
#
# ./data/preprocess.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_indicator.close/(temp_indicator.close.rolling(2).sum()-temp_indicator.close))-1
# ./data/preprocess.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   5).sum()/5)/temp_indicator.adjcp-1
# ./data/preprocess.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   10).sum()/10)/temp_indicator.adjcp-1
# ./data/preprocess.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   15).sum()/15)/temp_indicator.adjcp-1
# ./data/preprocess.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   20).sum()/20)/temp_indicator.adjcp-1
# ./data/preprocess.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   25).sum()/25)/temp_indicator.adjcp-1
# ./data/preprocess.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   30).sum()/30)/temp_indicator.adjcp-1
# ./experiment/dj30/td3/results
# 2022-05-17 01:37:05,496	INFO services.py:1376 -- View the Ray dashboard at http://127.0.0.1:8265
# 2022-05-17 01:37:07,606	INFO simple_q.py:154 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting `simple_optimizer=True` if this doesn't work for you.
# 2022-05-17 01:37:07,608	INFO trainer.py:792 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2022-05-17 01:37:07,610	WARNING deprecation.py:46 -- DeprecationWarning: `config['buffer_size']` has been deprecated. Use `config['replay_buffer_config']['capacity']` instead. This will raise an error in the future!
# (RolloutWorker pid=715979) 2022-05-17 01:37:11,100	WARNING deprecation.py:46 -- DeprecationWarning: `rllib.env.remote_vector_env.RemoteVectorEnv` has been deprecated. Use `ray.rllib.env.remote_base_env.RemoteBaseEnv` instead. This will raise an error in the future!
# /home/sunshuo/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/rllib/agents/ddpg/ddpg_torch_model.py:103: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729047590/work/torch/csrc/utils/tensor_numpy.cpp:141.)
#   torch.from_numpy(self.action_space.low).float())
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_664953/2028702883.py in <module>
#       2 for seed in [12345,23451,34512,45123,51234]:
#       3     a = TradeMaster(path=path,data="dj30",algorithms="td3",seed=seed,train_env=TradingEnv,test_env=TestingEnv)
# ----> 4     a.train_with_valid()
#       5     a.test()
#       6 a.get_report()
#
# ~/qml/trademaster_new/RLutil/agent.py in train_with_valid(self)
#      86         self.trainer = self.trainer(env=self.train_env, config=self.model_config)
#      87         for i in range(self.num_epochs):
# ---> 88             self.trainer.train()
#      89             valid_env_instance = self.test_env(self.valid_config)
#      90             state = valid_env_instance.reset()
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/tune/trainable.py in train(self)
#     313         """
#     314         start = time.time()
# --> 315         result = self.step()
#     316         assert isinstance(result, dict), "step() needs to return a dict."
#     317
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/rllib/agents/trainer.py in step(self)
#     961                 # Try to train one step.
#     962                 try:
# --> 963                     step_attempt_results = self.step_attempt()
#     964                 # @ray.remote RolloutWorker failure.
#     965                 except RayError as e:
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/rllib/agents/trainer.py in step_attempt(self)
#    1040         # No evaluation necessary, just run the next training iteration.
#    1041         if not evaluate_this_iter:
# -> 1042             step_results = self._exec_plan_or_training_iteration_fn()
#    1043         # We have to evaluate in this training iteration.
#    1044         else:
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/rllib/agents/trainer.py in _exec_plan_or_training_iteration_fn(self)
#    1960             results = self.training_iteration()
#    1961         else:
# -> 1962             results = next(self.train_exec_impl)
#    1963         return results
#    1964
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in __next__(self)
#     754     def __next__(self):
#     755         self._build_once()
# --> 756         return next(self.built_iterator)
#     757
#     758     def __str__(self):
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in apply_filter(it)
#     841     def filter(self, fn: Callable[[T], bool]) -> "LocalIterator[T]":
#     842         def apply_filter(it):
# --> 843             for item in it:
#     844                 with self._metrics_context():
#     845                     if isinstance(item, _NextValueNotReady) or fn(item):
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in apply_filter(it)
#     841     def filter(self, fn: Callable[[T], bool]) -> "LocalIterator[T]":
#     842         def apply_filter(it):
# --> 843             for item in it:
#     844                 with self._metrics_context():
#     845                     if isinstance(item, _NextValueNotReady) or fn(item):
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in apply_filter(it)
#     841     def filter(self, fn: Callable[[T], bool]) -> "LocalIterator[T]":
#     842         def apply_filter(it):
# --> 843             for item in it:
#     844                 with self._metrics_context():
#     845                     if isinstance(item, _NextValueNotReady) or fn(item):
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in build_union(timeout)
#    1073                     try:
#    1074                         for _ in range(max_pull):
# -> 1075                             item = next(it)
#    1076                             if isinstance(item, _NextValueNotReady):
#    1077                                 if timeout is not None:
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in __next__(self)
#     754     def __next__(self):
#     755         self._build_once()
# --> 756         return next(self.built_iterator)
#     757
#     758     def __str__(self):
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in base_iterator(timeout)
#     470                 try:
#     471                     yield ray.get(futures, timeout=timeout)
# --> 472                     futures = [a.par_iter_next.remote() for a in active]
#     473                     # Always yield after each round of gets with timeout.
#     474                     if timeout is not None:
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/iter.py in <listcomp>(.0)
#     470                 try:
#     471                     yield ray.get(futures, timeout=timeout)
# --> 472                     futures = [a.par_iter_next.remote() for a in active]
#     473                     # Always yield after each round of gets with timeout.
#     474                     if timeout is not None:
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/actor.py in remote(self, *args, **kwargs)
#     122
#     123     def remote(self, *args, **kwargs):
# --> 124         return self._remote(args, kwargs)
#     125
#     126     def options(self, **options):
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/util/tracing/tracing_helper.py in _start_span(self, args, kwargs, *_args, **_kwargs)
#     408             if kwargs is not None:
#     409                 assert "_ray_trace_ctx" not in kwargs
# --> 410             return method(self, args, kwargs, *_args, **_kwargs)
#     411
#     412         class_name = (self._actor_ref()
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/actor.py in _remote(self, args, kwargs, name, num_returns, concurrency_group)
#     170             invocation = self._decorator(invocation)
#     171
# --> 172         return invocation(args, kwargs)
#     173
#     174     def __getstate__(self):
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/actor.py in invocation(args, kwargs)
#     164                 name=name,
#     165                 num_returns=num_returns,
# --> 166                 concurrency_group_name=concurrency_group)
#     167
#     168         # Apply the decorator if there is one.
#
# ~/miniconda3/envs/FinRL/lib/python3.7/site-packages/ray/actor.py in _actor_method_call(self, method_name, args, kwargs, name, num_returns, concurrency_group_name)
#    1018             list_args, name, num_returns, self._ray_actor_method_cpus,
#    1019             concurrency_group_name
# -> 1020             if concurrency_group_name is not None else b"")
#    1021
#    1022         if len(object_refs) == 1:
#
# KeyboardInterrupt:
